# mean   2006.000000  12719.227586   5536.720690  14254.644828   6732.137931
# std       8.514693  11543.977127   4728.705512  11481.657587   5603.402084
# min    1992.000000    710.200000    411.000000   1278.500000    551.100000
# 25%    1999.000000   2759.800000   1435.600000   4158.900000   1667.100000
# 50%    2006.000000   8387.000000   3538.200000  10043.000000   4713.600000
# 75%    2013.000000  21134.600000   9945.400000  24259.600000  11836.400000
# max    2020.000000  36102.600000  14083.700000  36206.900000  17651.900000
#
#        Inner Mongolia      Liaoning         Jilin  Heilongjiang      Shanghai  \
# count       29.000000     29.000000     29.000000      29.00000     29.000000
# mean      6485.582759  11209.541379   5135.641379    6601.07931  14671.379310
# std       5790.702936   7953.052425   4075.496558    4470.22818  12149.921416
# min        421.700000   1473.000000    558.100000     857.40000   1114.300000
# 25%       1379.300000   4171.700000   1673.000000    2536.90000   4222.300000
# 50%       4161.800000   8390.300000   3226.500000    5329.80000  10598.900000
# 75%      11392.400000  19208.800000   9427.900000   11690.00000  23204.100000
# max      17359.800000  25115.000000  12311.300000   13698.50000  38700.600000
#
#        ...     Chongqing       Sichuan       Guizhou        Yunnan  \
# count  ...     29.000000     29.000000     29.000000     29.000000
# mean   ...   7843.668966  15689.603448   5036.268966   7647.300000
# std    ...   7803.860056  15000.862075   5464.615192   7392.931623
# min    ...    462.500000   1177.300000    339.900000    618.700000
# 25%    ...   1687.800000   3649.100000    937.500000   1899.800000
# 50%    ...   3900.300000   8494.700000   2264.100000   4090.700000
# 75%    ...  13027.600000  26518.000000   7973.100000  12825.500000
# max    ...  25002.800000  48598.800000  17826.600000  24521.900000
#
#              Tibet       Shaanxi        Gansu      Qinghai      Ningxia  \
# count    29.000000     29.000000    29.000000    29.000000    29.000000
# mean    529.958621   8744.458621  3377.065517  1026.158621  1314.896552
# std     552.430037   8607.792584  2872.867915   953.564196  1254.865638
# min      33.300000    531.600000   317.800000    87.500000    83.100000
# 25%     106.000000   1592.600000   956.300000   239.400000   264.600000
# 50%     285.900000   4595.600000  2203.000000   585.200000   683.300000
# 75%     828.200000  15905.400000  6014.500000  1713.300000  2327.700000
# max    1902.700000  26181.900000  9016.700000  3005.900000  3920.600000
#
#            Xinjiang
# count     29.000000
# mean    4818.386207
# std     4375.124693
# min      402.300000
# 25%     1163.200000
# 50%     2957.300000
# 75%     8392.600000
# max    13797.600000
#
# [8 rows x 32 columns]

# %%
chinapib=df_1.melt(id_vars=['años'],var_name=['provincia'], value_name='PIB')
chinapib.head()
# Out:
#    años provincia      PIB
# 0  2020   Beijing  36102.6
# 1  2019   Beijing  35445.1
# 2  2018   Beijing  33106.0
# 3  2017   Beijing  29883.0
# 4  2016   Beijing  27041.2

# %%
chinapib[["provincia","años","PIB"]].sort_values(["provincia","años"]).reset_index(drop=True)
# Out:
#     provincia  años      PIB
# 0       Anhui  1992    827.0
# 1       Anhui  1993   1073.5
# 2       Anhui  1994   1378.9
# 3       Anhui  1995   1891.2
# 4       Anhui  1996   2199.7
# ..        ...   ...      ...
# 894  Zhejiang  2016  47254.0
# 895  Zhejiang  2017  52403.1
# 896  Zhejiang  2018  58002.8
# 897  Zhejiang  2019  62462.0
# 898  Zhejiang  2020  64613.3
#
# [899 rows x 3 columns]

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x="provincia",y="PIB",data=chinapib)
plt.xticks(rotation=45);
plt.ylabel("PIB: cien millones de CNY¥")
plt.title("Distribución del PIB provincial chino durante 1992-2020" ,fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribución del PIB provincial chino durante 1992-2020')

# %%
plt.figure(figsize=(15,10))
grid=sns.FacetGrid(data=chinapib,col='provincia',col_wrap=4,hue="provincia",palette="pastel")
grid.map(plt.plot,"años","PIB")
grid.set_ylabels("PIB: cien millones de CNY¥")
plt.show();

# %%
import plotly as py
import plotly.graph_objs as go
import json

# %%
with open('china_geojson.json') as file:
    china_geojson = json.load(file)

# %%
def china_map(años):
   
    df_filtered = chinapib[chinapib.años==años]
    
   
    fig = go.Figure(go.Choroplethmapbox(geojson=china_geojson,
                                        locations=df_filtered.provincia, 
                                        z=df_filtered.PIB,
                                        colorscale='YlGn', 
                                        colorbar_ticksuffix = ' cien millones de CNY¥',
                                        colorbar_title = 'Valor del PIB provincial chino',
                                        marker_opacity=0.5, 
                                        marker_line_width=1))
    fig.update_layout(title_text=f'Annual GDP in {años}',
                      mapbox_style='white-bg',
                      mapbox_zoom=3, mapbox_center = {'lat': 37, 'lon': 110})
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    
    plt.figure(figsize=(8,10))

    fig.show()

# %%
china_map(1992)

# %%
chinapib[chinapib["años"]==1992]
# Out:
#      años       provincia     PIB
# 28   1992         Beijing   710.2
# 57   1992         Tianjin   411.0
# 86   1992           Hebei  1278.5
# 115  1992          Shanxi   551.1
# 144  1992  Inner Mongolia   421.7
# 173  1992        Liaoning  1473.0
# 202  1992           Jilin   558.1
# 231  1992    Heilongjiang   857.4
# 260  1992        Shanghai  1114.3
# 289  1992         Jiangsu  2136.0
# 318  1992        Zhejiang  1375.7
# 347  1992           Anhui   827.0
# 376  1992          Fujian   784.7
# 405  1992         Jiangxi   572.6
# 434  1992        Shandong  2196.5
# 463  1992           Henan  1279.8
# 492  1992           Hubei  1088.4
# 521  1992           Hunan   987.0
# 550  1992       Guangdong  2447.5
# 579  1992         Guangxi   646.6
# 608  1992          Hainan   184.9
# 637  1992       Chongqing   462.5
# 666  1992         Sichuan  1177.3
# 695  1992         Guizhou   339.9
# 724  1992          Yunnan   618.7
# 753  1992           Tibet    33.3
# 782  1992         Shaanxi   531.6
# 811  1992           Gansu   317.8
# 840  1992         Qinghai    87.5
# 869  1992         Ningxia    83.1
# 898  1992        Xinjiang   402.3

# %%
china_map(2020)

# %%
chinapib[chinapib["años"]==2020]
# Out:
#      años       provincia       PIB
# 0    2020         Beijing   36102.6
# 29   2020         Tianjin   14083.7
# 58   2020           Hebei   36206.9
# 87   2020          Shanxi   17651.9
# 116  2020  Inner Mongolia   17359.8
# 145  2020        Liaoning   25115.0
# 174  2020           Jilin   12311.3
# 203  2020    Heilongjiang   13698.5
# 232  2020        Shanghai   38700.6
# 261  2020         Jiangsu  102719.0
# 290  2020        Zhejiang   64613.3
# 319  2020           Anhui   38680.6
# 348  2020          Fujian   43903.9
# 377  2020         Jiangxi   25691.5
# 406  2020        Shandong   73129.0
# 435  2020           Henan   54997.1
# 464  2020           Hubei   43443.5
# 493  2020           Hunan   41781.5
# 522  2020       Guangdong  110760.9
# 551  2020         Guangxi   22156.7
# 580  2020          Hainan    5532.4
# 609  2020       Chongqing   25002.8
# 638  2020         Sichuan   48598.8
# 667  2020         Guizhou   17826.6
# 696  2020          Yunnan   24521.9
# 725  2020           Tibet    1902.7
# 754  2020         Shaanxi   26181.9
# 783  2020           Gansu    9016.7
# 812  2020         Qinghai    3005.9
# 841  2020         Ningxia    3920.6
# 870  2020        Xinjiang   13797.6

# %%
df_2=pd.read_csv("tasa_de_pobreza.csv")
df_2.head(2)
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1          NaN          AFE
#
#                                       Indicator Name Indicator Code  1960  \
# 0  Tasa de incidencia de la pobreza, sobre la bas...    SI.POV.DDAY   NaN
# 1  Tasa de incidencia de la pobreza, sobre la bas...    SI.POV.DDAY   NaN
#
#    1961  1962  1963  1964  1965  ...  2013  2014  2015  2016  2017  2018  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2019  2020  2021  Unnamed: 66
# 0   NaN   NaN   NaN          NaN
# 1   NaN   NaN   NaN          NaN
#
# [2 rows x 67 columns]

# %%
china_pobreza=df_2[df_2["Country Code"]=="CHN"].loc[:,"1992":"2020"].T.reset_index(drop=False)
china_pobreza
# Out:
#    index    40
# 0   1992   NaN
# 1   1993  56.7
# 2   1994   NaN
# 3   1995   NaN
# 4   1996  41.7
# 5   1997   NaN
# 6   1998   NaN
# 7   1999  40.3
# 8   2000   NaN
# 9   2001   NaN
# 10  2002  31.7
# 11  2003   NaN
# 12  2004   NaN
# 13  2005  18.5
# 14  2006   NaN
# 15  2007   NaN
# 16  2008  14.9
# 17  2009   NaN
# 18  2010  11.2
# 19  2011   7.9
# 20  2012   6.5
# 21  2013   1.9
# 22  2014   1.4
# 23  2015   0.7
# 24  2016   0.5
# 25  2017   0.4
# 26  2018   0.3
# 27  2019   0.1
# 28  2020   NaN

# %%
china_pobreza.rename(columns={"index":"años",40:"tasa de pobreza"},inplace=True)
china_pobreza
# Out:
#     años  tasa de pobreza
# 0   1992              NaN
# 1   1993             56.7
# 2   1994              NaN
# 3   1995              NaN
# 4   1996             41.7
# 5   1997              NaN
# 6   1998              NaN
# 7   1999             40.3
# 8   2000              NaN
# 9   2001              NaN
# 10  2002             31.7
# 11  2003              NaN
# 12  2004              NaN
# 13  2005             18.5
# 14  2006              NaN
# 15  2007              NaN
# 16  2008             14.9
# 17  2009              NaN
# 18  2010             11.2
# 19  2011              7.9
# 20  2012              6.5
# 21  2013              1.9
# 22  2014              1.4
# 23  2015              0.7
# 24  2016              0.5
# 25  2017              0.4
# 26  2018              0.3
# 27  2019              0.1
# 28  2020              NaN

# %%
china_pobreza["tasa de pobreza"].fillna(method='ffill',inplace=True)
china_pobreza
# Out:
#     años  tasa de pobreza
# 0   1992              NaN
# 1   1993             56.7
# 2   1994             56.7
# 3   1995             56.7
# 4   1996             41.7
# 5   1997             41.7
# 6   1998             41.7
# 7   1999             40.3
# 8   2000             40.3
# 9   2001             40.3
# 10  2002             31.7
# 11  2003             31.7
# 12  2004             31.7
# 13  2005             18.5
# 14  2006             18.5
# 15  2007             18.5
# 16  2008             14.9
# 17  2009             14.9
# 18  2010             11.2
# 19  2011              7.9
# 20  2012              6.5
# 21  2013              1.9
# 22  2014              1.4
# 23  2015              0.7
# 24  2016              0.5
# 25  2017              0.4
# 26  2018              0.3
# 27  2019              0.1
# 28  2020              0.1
